# %% [markdown]
# <a href="https://colab.research.google.com/github/JouichatKhadija/.github.io/blob/main/TP1DataMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP 1 : Exploration des données
#
#
# L’exploration des données désigne l’investigation préliminaire d’un jeu de données afin de mieux comprendre ses caractéristiques spécifiques.
#
# Elle a deux motivations principales :
# 1. Aider les utilisateurs à choisir la technique appropriée de prétraitement et d’analyse des données.
# 2. Exploiter la capacité humaine à reconnaître des motifs dans les données.
#
# Lisez attentivement les instructions étape par étape ci-dessous.

# %% [markdown]
# ## 3.1. Statistiques descriptives
#
# Les statistiques descriptives sont des quantités, comme la moyenne et l’écart-type, qui résument différentes caractéristiques d’un ensemble potentiellement très grand de valeurs à l’aide d’un seul nombre ou d’un petit ensemble de nombres. Dans cet atelier, nous utiliserons l’échantillon de données **Iris**, qui contient des informations sur 150 fleurs d’iris, à raison de 50 fleurs pour chacune des trois espèces : Setosa, Versicolour et Virginica. Chaque fleur est décrite par cinq attributs :
#
# - longueur du sépale en centimètres
#
# - largeur du sépale en centimètres
#
# - longueur du pétale en centimètres
#
# - largeur du pétale en centimètres
#
# - classe (Setosa, Versicolour, Virginica)
#
# Dans cet exercice, vous devez :
#
# - Charger un fichier de données CSV dans un objet **Pandas DataFrame**.
#
# - Calculer différentes statistiques descriptives à partir du **DataFrame**.
#
# PS: assurez-vous d’avoir installé la bibliothèque **Pandas**.

# %% [markdown]
# **<font color='red'>Consignes :</font>**
#
# **1.a** Tout d’abord, vous devez télécharger le <a href="http://archive.ics.uci.edu/ml/datasets/Iris">jeu de données Iris</a> depuis le dépôt UCI de machine learning.
#
# **1.b** Puis, utilisez **Pandas** pour lire le fichier CSV et le stocker dans un objet **DataFrame** nommé `data`.
#
# **1.c** Enfin, affichez les cinq premières lignes du tableau de données.
#
# **<font color="red">Code :</font>**

# %%
# Out:
#    longueur sepale  largeur sepale  longueur petale  largeur petale  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# **2.** Pour chaque attribut quantitatif, calculez sa moyenne, son écart-type, sa valeur minimale et sa valeur maximale.
#
# **<font color="red">Code :</font>**

# %%
# Out:
# longueur sepale:
# 	 Moyenne = 5.84
# 	 Ecart-type = 0.83
# 	 Minimum = 4.30
# 	 Maximum = 7.90
# largeur sepale:
# 	 Moyenne = 3.05
# 	 Ecart-type = 0.43
# 	 Minimum = 2.00
# 	 Maximum = 4.40
# longueur petale:
# 	 Moyenne = 3.76
# 	 Ecart-type = 1.76
# 	 Minimum = 1.00
# 	 Maximum = 6.90
# largeur petale:
# 	 Moyenne = 1.20
# 	 Ecart-type = 0.76
# 	 Minimum = 0.10
# 	 Maximum = 2.50

# %% [markdown]
# **3.** Pour l’attribut qualitatif (`classe`), comptez la fréquence de chacune de ses valeurs distinctes.
#
# **<font color="red">Code :</font>**

# %%
# Out:
# classe
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **4.** Il est également possible d’afficher simultanément le résumé de tous les attributs sous forme de tableau en utilisant la fonction `describe()`. Si un attribut est quantitatif, elle affichera sa moyenne, son écart-type ainsi que différents quantiles (y compris le minimum, la médiane et le maximum). Si un attribut est qualitatif, elle affichera son nombre de valeurs uniques ainsi que la valeur la plus fréquente.
#
# **<font color="red">Code :</font>**

# %%
# Out:
#         longueur sépale  largeur sépale  longueur pétale  largeur pétale  \
# count        150.000000      150.000000       150.000000      150.000000
# unique              NaN             NaN              NaN             NaN
# top                 NaN             NaN              NaN             NaN
# freq                NaN             NaN              NaN             NaN
# mean           5.843333        3.054000         3.758667        1.198667
# std            0.828066        0.433594         1.764420        0.763161
# min            4.300000        2.000000         1.000000        0.100000
# 25%            5.100000        2.800000         1.600000        0.300000
# 50%            5.800000        3.000000         4.350000        1.300000
# 75%            6.400000        3.300000         5.100000        1.800000
# max            7.900000        4.400000         6.900000        2.500000
#
#              classe
# count           150
# unique            3
# top     Iris-setosa
# ...

# %% [markdown]
# Notez que `count` correspond au nombre de valeurs non manquantes pour chaque attribut.

# %% [markdown]
# **5.** Pour les statistiques multivariées, vous pouvez calculer la covariance et la corrélation entre des paires d’attributs.
#
# **<font color="red">Code :</font>**

# %%
# Out:
# Covariance :
#                  longueur sépale  largeur sépale  longueur pétale  \
# longueur sépale         0.685694       -0.039268         1.273682
# largeur sépale         -0.039268        0.188004        -0.321713
# longueur pétale         1.273682       -0.321713         3.113179
# largeur pétale          0.516904       -0.117981         1.296387
#
#                  largeur pétale
# longueur sépale        0.516904
# largeur sépale        -0.117981
# longueur pétale        1.296387
# largeur pétale         0.582414

# %%
# Out:
# Corrélation :
#                  longueur sépale  largeur sépale  longueur pétale  \
# longueur sépale         1.000000       -0.109369         0.871754
# largeur sépale         -0.109369        1.000000        -0.420516
# longueur pétale         0.871754       -0.420516         1.000000
# largeur pétale          0.817954       -0.356544         0.962757
#
#                  largeur pétale
# longueur sépale        0.817954
# largeur sépale        -0.356544
# longueur pétale        0.962757
# largeur pétale         1.000000

# %% [markdown]
# ## 3.2. Visualisation des données
#
# La visualisation des données consiste à présenter l’information sous forme graphique ou tabulaire. Une visualisation réussie exige que les données (ou l’information) soient converties dans un format visuel afin que les caractéristiques des données ainsi que les relations entre les objets ou les attributs puissent être analysées ou communiquées.
#
# Dans ce tutoriel, vous apprendrez à afficher les données **Iris** créées dans la section 3.1. Pour exécuter le programme d’exemple présenté ici, assurez-vous d’avoir installé la bibliothèque **matplotlib** (voir le Module 0 pour savoir comment installer des packages Python).

# %% [markdown]
# **1.** Nous allons d’abord afficher l’histogramme de l’attribut **longueur du sépale** en le discrétisant en 8 classes distinctes, puis en comptant la fréquence dans chaque classe.
#
# **<font color="red">Code :</font>**

# %% [markdown]
# **2.** Un diagramme en boîte (*boxplot*) peut également être utilisé pour montrer la distribution des valeurs de chaque attribut.
#
# **<font color="red">Code :</font>**

# %%
# Out:
# <Axes: >

# %% [markdown]
# **3.** Pour chaque paire d’attributs, nous pouvons utiliser un nuage de points (*scatter plot*) afin de visualiser leur distribution conjointe.
#
# **<font color="red">Code :</font>**

# %% [markdown]
# **4.** Les coordonnées parallèles peuvent être utilisées pour afficher simultanément tous les points de données. Elles disposent d’un axe de coordonnées pour chaque attribut, mais ces axes sont parallèles les uns aux autres au lieu d’être perpendiculaires, comme c’est traditionnellement le cas. De plus, un objet est représenté par une ligne plutôt que par un point. Dans l’exemple ci-dessous, la distribution des valeurs de chaque classe peut être identifiée par une couleur différente.
#
# **<font color="red">Code :</font>**

# %%
# Out:
# <Axes: >

# %% [markdown]
# ## 3.4. Exercices supplémentaires
#
# Les exercices suivants prolongent le même travail d’exploration et de visualisation sur le jeu de données **Iris**.
# Ils utilisent les mêmes variables et bibliothèques que dans le reste du notebook.

# %% [markdown]
# ### Exercice 1 — Médiane et quartiles
#
# Pour chaque attribut quantitatif, affichez :
#
# - la médiane,
# - le premier quartile (Q1),
# - le troisième quartile (Q3),
# - l’étendue interquartile (IQR = Q3 - Q1).

# %%
# Out:
# longueur sépale :
# 	Q1 = 5.10
# 	Médiane = 5.80
# 	Q3 = 6.40
# 	IQR = 1.30
#
# largeur sépale :
# 	Q1 = 2.80
# 	Médiane = 3.00
# 	Q3 = 3.30
# 	IQR = 0.50
#
# longueur pétale :
# 	Q1 = 1.60
# 	Médiane = 4.35
# 	Q3 = 5.10
# 	IQR = 3.50
#
# largeur pétale :
# 	Q1 = 0.30
# 	Médiane = 1.30
# 	Q3 = 1.80
# 	IQR = 1.50

# %% [markdown]
# ### Exercice 2 — Moyennes par classe
#
# Calculez la moyenne de chaque attribut quantitatif **pour chaque espèce d’iris**.
# Observez ensuite quelles espèces semblent avoir les pétales les plus longs et les plus larges.

# %%
# Out:
#                  longueur sépale  largeur sépale  longueur pétale  \
# Iris-setosa                5.006           3.418            1.464
# Iris-versicolor            5.936           2.770            4.260
# Iris-virginica             6.588           2.974            5.552
#
#                  largeur pétale
# Iris-setosa               0.244
# Iris-versicolor           1.326
# Iris-virginica            2.026

# %%
# Out:
#                  longueur sépale  largeur sépale  longueur pétale  \
# classe
# Iris-setosa                5.006           3.418            1.464
# Iris-versicolor            5.936           2.770            4.260
# Iris-virginica             6.588           2.974            5.552
#
#                  largeur pétale
# classe
# Iris-setosa               0.244
# Iris-versicolor           1.326
# Iris-virginica            2.026

# %% [markdown]
# ### Exercice 3 — Attributs les plus corrélés
#
# Calculez la matrice de corrélation entre les attributs quantitatifs, puis identifiez la paire d’attributs ayant la corrélation absolue la plus élevée (hors diagonale).

# %%
# Out:
# Matrice de corrélation :
#                  longueur sépale  largeur sépale  longueur pétale  \
# longueur sépale         1.000000       -0.109369         0.871754
# largeur sépale         -0.109369        1.000000        -0.420516
# longueur pétale         0.871754       -0.420516         1.000000
# largeur pétale          0.817954       -0.356544         0.962757
#
#                  largeur pétale
# longueur sépale        0.817954
# largeur sépale        -0.356544
# longueur pétale        0.962757
# largeur pétale         1.000000
# Paire la plus corrélée : longueur pétale / largeur pétale
# Corrélation = 0.963

# %% [markdown]
# ### Exercice 4 — Histogrammes de tous les attributs numériques
#
# Affichez les histogrammes des quatre attributs quantitatifs dans une seule figure.
# Choisissez un nombre de classes raisonnable (par exemple 8 ou 10).

# %%
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# x.ravel() =[1 2 3 4 5 6 7 8 9]
# x.flatten()=[1 2 3 4 5 6 7 8 9]

# %% [markdown]
# ### Exercice 5 — Diagrammes en boîte par classe
#
# Tracez un diagramme en boîte de la **longueur pétale** en fonction de la **classe**.
# Puis faites de même pour la **largeur pétale**.
# Interprétez visuellement les différences entre espèces.

# %% [markdown]
# ### Exercice 6 — Nuage de points coloré par classe
#
# Réalisez un nuage de points entre :
#
# - **longueur pétale** en abscisse,
# - **largeur pétale** en ordonnée,
#
# en coloriant les points selon la classe.
# Essayez ensuite de répondre à la question suivante :
# **les classes semblent-elles bien séparées dans cet espace ?**

# %% [markdown]
# ### Exercice 7 — Valeurs extrêmes
#
# Pour chaque attribut quantitatif, identifiez :
#
# - l’indice de la valeur minimale,
# - l’indice de la valeur maximale,
# - la classe associée à ces observations extrêmes.

# %%
# Out:
# longueur sépale :
# 	Minimum = 4.30 (ligne 13, classe = Iris-setosa)
# 	Maximum = 7.90 (ligne 131, classe = Iris-virginica)
# largeur sépale :
# 	Minimum = 2.00 (ligne 60, classe = Iris-versicolor)
# 	Maximum = 4.40 (ligne 15, classe = Iris-setosa)
# longueur pétale :
# 	Minimum = 1.00 (ligne 22, classe = Iris-setosa)
# 	Maximum = 6.90 (ligne 118, classe = Iris-virginica)
# largeur pétale :
# 	Minimum = 0.10 (ligne 9, classe = Iris-setosa)
# 	Maximum = 2.50 (ligne 100, classe = Iris-virginica)

# %% [markdown]
# ### Exercice 8 — Mini défi d’interprétation
#
# Répondez brièvement aux questions suivantes après avoir exécuté les cellules précédentes :
#
# 1. Quel attribut semble le plus discriminant entre les classes ?
# 2. Quelle paire d’attributs paraît la plus corrélée ?
# 3. Quelle classe semble la plus facile à distinguer visuellement ?
# 4. Les distributions observées paraissent-elles symétriques ou asymétriques ?
# 5. Voyez-vous des valeurs potentiellement atypiques ?

# %% [markdown]
# ### Exercice 9 — Défi bonus : matrice de dispersion
#
# Utilisez `pd.plotting.scatter_matrix(...)` pour afficher automatiquement la matrice des nuages de points des attributs quantitatifs.
# Que remarquez-vous par rapport aux graphiques tracés manuellement plus haut ?

# %% [markdown]
# ## 3.3. Résumé
#
# Ce tutoriel présente plusieurs exemples d’exploration et de visualisation des données à l’aide des bibliothèques **Pandas** et **matplotlib** disponibles en Python. Il a également été enrichi par une série d’exercices pour consolider la pratique sur le jeu de données **Iris**.
#
# **<font color='blue'>Références :</font>**
#
# 1. Documentation de Pandas. https://pandas.pydata.org/
# 2. Documentation de matplotlib. https://matplotlib.org/
# 3. Lichman, M. (2013). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
